# %%
pip -q install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip -q install -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip -q install xformers bitsandbytes
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%bash
# source /workspace/DreamBooth-CLoRA/.venv/bin/activate
#
# pip uninstall -y transformers tokenizers diffusers
# pip install --no-cache-dir "diffusers==0.30.3" "transformers==4.56.2"
# pip check
# Out:
# Found existing installation: transformers 5.3.0
# Uninstalling transformers-5.3.0:
#   Successfully uninstalled transformers-5.3.0
# Found existing installation: tokenizers 0.22.2
# Uninstalling tokenizers-0.22.2:
#   Successfully uninstalled tokenizers-0.22.2
# Found existing installation: diffusers 0.30.3
# Uninstalling diffusers-0.30.3:
#   Successfully uninstalled diffusers-0.30.3
# Collecting diffusers==0.30.3
#   Downloading diffusers-0.30.3-py3-none-any.whl.metadata (18 kB)
# Collecting transformers==4.56.2
#   Downloading transformers-4.56.2-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: importlib-metadata in ./.venv/lib/python3.12/site-packages (from diffusers==0.30.3) (8.7.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.12/site-packages (from diffusers==0.30.3) (3.20.0)
# Requirement already satisfied: huggingface-hub>=0.23.2 in ./.venv/lib/python3.12/site-packages (from diffusers==0.30.3) (1.6.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.12/site-packages (from diffusers==0.30.3) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.12/site-packages (from diffusers==0.30.3) (2026.2.28)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from diffusers==0.30.3) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in ./.venv/lib/python3.12/site-packages (from diffusers==0.30.3) (0.7.0)
# Requirement already satisfied: Pillow in ./.venv/lib/python3.12/site-packages (from diffusers==0.30.3) (12.0.0)
# Collecting huggingface-hub>=0.23.2 (from diffusers==0.30.3)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.12/site-packages (from transformers==4.56.2) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.12/site-packages (from transformers==4.56.2) (6.0.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers==4.56.2)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: tqdm>=4.27 in ./.venv/lib/python3.12/site-packages (from transformers==4.56.2) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.23.2->diffusers==0.30.3) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.23.2->diffusers==0.30.3) (1.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.12/site-packages (from huggingface-hub>=0.23.2->diffusers==0.30.3) (4.15.0)
# Requirement already satisfied: zipp>=3.20 in ./.venv/lib/python3.12/site-packages (from importlib-metadata->diffusers==0.30.3) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests->diffusers==0.30.3) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests->diffusers==0.30.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests->diffusers==0.30.3) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests->diffusers==0.30.3) (2026.2.25)
# Downloading diffusers-0.30.3-py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/2.7 MB ? eta -:--:--━━━━━━━━━━━ 2.7/2.7 MB 70.1 MB/s  0:00:00
# Downloading transformers-4.56.2-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/11.6 MB ? eta -:--:--━━━━━━━━━━━ 11.6/11.6 MB 221.4 MB/s  0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/566.4 kB ? eta -:--:--━━━━━━━━━━━ 566.4/566.4 kB 270.0 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/3.3 MB ? eta -:--:--━━━━━━━━━━━ 3.3/3.3 MB 214.7 MB/s  0:00:00
# Installing collected packages: huggingface-hub, tokenizers, diffusers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.6.0
#     Uninstalling huggingface_hub-1.6.0:
#       Successfully uninstalled huggingface_hub-1.6.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━ 0/4 [huggingface-hub]━━━━━━━━━━━━━━━━━ 2/4 [diffusers]━━━━━━━━━━━━━━━━━ 2/4 [diffusers]━━━━━━━━━━━━━━━━━ 2/4 [diffusers]━━━━━━━━━━━━━━━━━ 2/4 [diffusers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━╺━━━━━━━━━ 3/4 [transformers]━━━━━━━━━━━ 4/4 [transformers]
# Successfully installed diffusers-0.30.3 huggingface-hub-0.36.2 tokenizers-0.22.2 transformers-4.56.2
# No broken requirements found.

# %%
# %%bash
#
# python - <<'PY'
# import diffusers, transformers
# print("diffusers:", diffusers.__version__)
# print("transformers:", transformers.__version__)
# from diffusers import StableDiffusionPipeline
# print("StableDiffusionPipeline import OK")
# PY
# Out:
# diffusers: 0.30.3
# transformers: 4.56.2
# StableDiffusionPipeline import OK

# %%
# !bash run-naive-sequential.sh
# Out:
# 2026-03-08 22:06:21 | INFO     | dreambooth_clora | Loaded config from: configs/tasks_5char.yaml
# 2026-03-08 22:06:21 | INFO     | dreambooth_clora | Experiment: 5char_naive
# 2026-03-08 22:06:21 | INFO     | dreambooth_clora | Method: naive_sequential
# 2026-03-08 22:06:21 | INFO     | dreambooth_clora | Tasks: 1
# 2026-03-08 22:06:21 | INFO     | dreambooth_clora | Output: /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02
# 2026-03-08 22:06:21 | INFO     | dreambooth_clora | Global seed set to 42
# 2026-03-08 22:06:21 | INFO     | src.orchestrator.pipeline | ============================================================
# 2026-03-08 22:06:21 | INFO     | src.orchestrator.pipeline | CONTINUAL DREAMBOOTH-CLORA PIPELINE (LEGACY)
# 2026-03-08 22:06:21 | INFO     | src.orchestrator.pipeline | Method: naive_sequential
# 2026-03-08 22:06:21 | INFO     | src.orchestrator.pipeline | Tasks: 1
# 2026-03-08 22:06:21 | INFO     | src.orchestrator.pipeline | Output: /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive
# 2026-03-08 22:06:21 | INFO     | src.orchestrator.pipeline | ============================================================
# 2026-03-08 22:06:21 | INFO     | src.orchestrator.pipeline | Validating 1 task datasets...
# 2026-03-08 22:06:21 | INFO     | src.data.dataset | Task 'Miku': 10 training images, 6 reference images
# 2026-03-08 22:06:21 | INFO     | src.orchestrator.pipeline | All task datasets validated successfully
# 2026-03-08 22:06:22 | INFO     | src.training.trainer | Loading base model: hakurei/waifu-diffusion
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2026-03-08 22:06:25 | INFO     | src.training.trainer | Base models loaded and frozen
# 2026-03-08 22:06:25 | INFO     | src.orchestrator.pipeline |
# 2026-03-08 22:06:25 | INFO     | src.orchestrator.pipeline | ============================================================
# 2026-03-08 22:06:25 | INFO     | src.orchestrator.pipeline | TASK 1/1: Miku
# 2026-03-08 22:06:25 | INFO     | src.orchestrator.pipeline | ============================================================
# 2026-03-08 22:06:25 | INFO     | src.methods.naive_sequential | [NaiveSequential] Task 0: no continual-learning setup needed
# 2026-03-08 22:06:26 | INFO     | src.training.trainer | Injected fresh LoRA (rank=32, alpha=32, targets=['to_k', 'to_v'])
# 2026-03-08 22:06:26 | INFO     | src.training.trainer | Trainable params: 3444736 / 869355460 (0.40%)
# 2026-03-08 22:06:26 | INFO     | src.data.dataset | DreamBoothDataset: 10 images (×100 repeats) from /workspace/DreamBooth-CLoRA/configs/../nakano-debug/Miku-debug/train, prompt='sksmiku'
# Training [Miku]: 100%|███████| 1000/1000 [18:54<00:00,  1.13s/step, loss=0.1203]
# 2026-03-08 22:25:20 | INFO     | src.training.trainer | Training complete for 'Miku': 1000 steps, final loss=0.1203
# 2026-03-08 22:25:20 | INFO     | src.utils.io | Saved LoRA weights (PEFT) to /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/checkpoints/task_00_Miku/lora_weights
# 2026-03-08 22:25:20 | INFO     | src.training.trainer | Checkpoint saved to /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/checkpoints/task_00_Miku/lora_weights
# 2026-03-08 22:25:20 | INFO     | src.methods.naive_sequential | [NaiveSequential] Task 0: no post-task cleanup needed
# 2026-03-08 22:25:20 | INFO     | src.orchestrator.pipeline | Evaluating tasks 0..0 after training task 0
# Loading pipeline components...: 100%|█████████████| 6/6 [00:00<00:00, 13.28it/s]
# 2026-03-08 22:25:22 | INFO     | src.utils.io | Loaded PEFT LoRA into pipeline UNet from /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/checkpoints/task_00_Miku/lora_weights (adapter=default)
# 2026-03-08 22:25:22 | INFO     | src.eval.generator | Generating 4 images for prompt 1/6: 'sksmiku, portrait, white background'
# 2026-03-08 22:25:25 | INFO     | src.eval.generator | Generating 4 images for prompt 2/6: 'sksmiku, upper body, smiling'
# 2026-03-08 22:25:27 | INFO     | src.eval.generator | Generating 4 images for prompt 3/6: 'sksmiku, full body, standing'
# 2026-03-08 22:25:30 | INFO     | src.eval.generator | Generating 4 images for prompt 4/6: 'sksmiku, close-up face, detailed'
# 2026-03-08 22:25:33 | INFO     | src.eval.generator | Generating 4 images for prompt 5/6: 'sksmiku, looking to the side, soft lighting'
# 2026-03-08 22:25:36 | INFO     | src.eval.generator | Generating 4 images for prompt 6/6: 'sksmiku, chibi style, cute expression'
# 2026-03-08 22:25:38 | INFO     | src.eval.generator | Generated 24 evaluation images for 'Miku' -> /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/eval_images/stage_00/Miku
# CCIPMetrics Initializing:   0%|                           | 0/6 [00:00<?, ?it/s]2026-03-08 22:25:39 | INFO     | root | Model '/workspace/.hf_home/hub/models--deepghs--ccip_onnx/snapshots/eb2acdd29af1703388d3d0c04221add322bc9110/ccip-caformer-24-randaug-pruned/model_feat.onnx' loaded with provider 'CUDAExecutionProvider'
# CCIPMetrics Initializing: 100%|███████████████████| 6/6 [00:00<00:00,  8.72it/s]
# CCIPMetrics Calculating: 100%|█████████████████| 24/24 [00:00<00:00, 108.77it/s]
# 2026-03-08 22:25:40 | INFO     | root | Model '/workspace/.hf_home/hub/models--deepghs--ccip_onnx/snapshots/eb2acdd29af1703388d3d0c04221add322bc9110/ccip-caformer-24-randaug-pruned/model_metrics.onnx' loaded with provider 'CUDAExecutionProvider'
# 2026-03-08 22:25:40 | INFO     | src.eval.metrics | CCIP score: 0.0278 (generated=/workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/eval_images/stage_00/Miku, ref=/workspace/DreamBooth-CLoRA/configs/../nakano-debug/Miku-debug/ref)
# 2026-03-08 22:25:40 | INFO     | src.orchestrator.pipeline |   CCIP[stage=0, task=Miku] = 0.0278
# 2026-03-08 22:25:40 | INFO     | src.orchestrator.pipeline | Task 0 complete in 1155.2 seconds
# 2026-03-08 22:25:40 | INFO     | src.orchestrator.pipeline |
# 2026-03-08 22:25:40 | INFO     | src.orchestrator.pipeline | ============================================================
# 2026-03-08 22:25:40 | INFO     | src.orchestrator.pipeline | GENERATING FINAL REPORT
# 2026-03-08 22:25:40 | INFO     | src.orchestrator.pipeline | ============================================================
# 2026-03-08 22:25:40 | INFO     | src.eval.report | Score matrix CSV saved to /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/reports/score_matrix.csv
# 2026-03-08 22:25:40 | INFO     | src.eval.report | Metrics JSON saved to /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/reports/metrics.json
# 2026-03-08 22:25:41 | INFO     | src.eval.report | Heatmap saved to /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/reports/heatmap.png
# 2026-03-08 22:25:41 | INFO     | src.eval.report | Score progression chart saved to /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/reports/score_progression.png
# 2026-03-08 22:25:41 | INFO     | src.eval.report | Forgetting bar chart saved to /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/reports/forgetting_bar.png
# 2026-03-08 22:25:41 | INFO     | src.eval.report | Summary saved to /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive/reports/summary.txt
# 2026-03-08 22:25:41 | INFO     | src.eval.report |
# ============================================================
# CONTINUAL DREAMBOOTH-CLORA EVALUATION SUMMARY
# ============================================================
#
# Final Average Score:       0.0278
# Average Forgetting:       0.0000
# Avg Backward Transfer:    0.0000
#
# Per-Stage Average Scores:
#   After task 0 (Miku): 0.0278  [seen: Miku]
#
# Learning Accuracy (diagonal A[t][t]):
#   Miku: 0.0278
#
# Per-Task Forgetting:
#   Miku: 0.0000
#
# Score Matrix:
#                 Miku
# Stage 0:      0.0278
# ============================================================
# 2026-03-08 22:25:41 | INFO     | src.orchestrator.pipeline | Pipeline complete! Results saved to /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/5char_naive
# 2026-03-08 22:25:41 | INFO     | dreambooth_clora | Total elapsed time: 1159.6 seconds (19.3 minutes)

# %%
# !bash test-base-model.sh
# Out:
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Repo root: /workspace/DreamBooth-CLoRA
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Config: /workspace/DreamBooth-CLoRA/configs/tasks_5char.yaml
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Selected task: Miku
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Prompt mode: dreambooth
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Output dir: /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/debug/base_model_preview/Miku
# 2026-03-08 22:50:02 | INFO     | src.training.trainer | Loading base model: hakurei/waifu-diffusion
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2026-03-08 22:50:05 | INFO     | src.training.trainer | Base models loaded and frozen
# Loading pipeline components...: 100%|█████████████| 6/6 [00:00<00:00, 12.27it/s]
# 2026-03-08 22:50:06 | INFO     | src.eval.generator | Generating 4 images for prompt 1/6: 'sksmiku, portrait, white background'
# 2026-03-08 22:50:08 | INFO     | src.eval.generator | Generating 4 images for prompt 2/6: 'sksmiku, upper body, smiling'
# 2026-03-08 22:50:11 | INFO     | src.eval.generator | Generating 4 images for prompt 3/6: 'sksmiku, full body, standing'
# 2026-03-08 22:50:13 | INFO     | src.eval.generator | Generating 4 images for prompt 4/6: 'sksmiku, close-up face, detailed'
# 2026-03-08 22:50:16 | INFO     | src.eval.generator | Generating 4 images for prompt 5/6: 'sksmiku, looking to the side, soft lighting'
# 2026-03-08 22:50:19 | INFO     | src.eval.generator | Generating 4 images for prompt 6/6: 'sksmiku, chibi style, cute expression'
# 2026-03-08 22:50:21 | INFO     | src.eval.generator | Generated 24 evaluation images for 'Miku' -> /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/debug/base_model_preview/Miku
# ================================================================================
# BASE MODEL PREVIEW COMPLETE
# Task          : Miku
# Prompt mode   : dreambooth
# Images saved  : 24
# Output folder : /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/debug/base_model_preview/Miku
# ================================================================================
