# %%
pip -q install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip -q install -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip -q install xformers bitsandbytes
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %%bash
# source /workspace/DreamBooth-CLoRA/.venv/bin/activate
#
# pip uninstall -y transformers tokenizers diffusers
# pip install --no-cache-dir "diffusers==0.30.3" "transformers==4.56.2"
# pip check
# Out:
# Found existing installation: transformers 5.3.0
# Uninstalling transformers-5.3.0:
#   Successfully uninstalled transformers-5.3.0
# Found existing installation: tokenizers 0.22.2
# Uninstalling tokenizers-0.22.2:
#   Successfully uninstalled tokenizers-0.22.2
# Found existing installation: diffusers 0.30.3
# Uninstalling diffusers-0.30.3:
#   Successfully uninstalled diffusers-0.30.3
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/2.7 MB ? eta -:--:--━━━━━━━━━━━ 2.7/2.7 MB 70.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/11.6 MB ? eta -:--:--━━━━━━━━━━━ 11.6/11.6 MB 221.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/566.4 kB ? eta -:--:--━━━━━━━━━━━ 566.4/566.4 kB 270.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/3.3 MB ? eta -:--:--━━━━━━━━━━━ 3.3/3.3 MB 214.7 MB/s  0:00:00
# ...
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.6.0
#     Uninstalling huggingface_hub-1.6.0:
# ...

# %%
# %%bash
#
# python - <<'PY'
# import diffusers, transformers
# print("diffusers:", diffusers.__version__)
# print("transformers:", transformers.__version__)
# from diffusers import StableDiffusionPipeline
# print("StableDiffusionPipeline import OK")
# PY
# Out:
# diffusers: 0.30.3
# transformers: 4.56.2
# StableDiffusionPipeline import OK

# %%
# !bash run-naive-sequential.sh
# Out:
# run-naive-sequential.sh: line 3: $'\r': command not found
# run-naive-sequential.sh: line 5: $'\r': command not found
# : No such file or directoryequential.sh
# chmod: cannot access 'run-naive-sequential.sh'$'\r': No such file or directory
# run-naive-sequential.sh: line 8: $'\r': command not found
# run-naive-sequential.sh: line 10: cd: $'/workspace/Continual-DreamBooth-LoRA\r\r': No such file or directory
# run-naive-sequential.sh: line 11: $'\r': command not found
# usage: main.py [-h] --config CONFIG [--dry-run] [--eval-only CHECKPOINT_DIR]
#                [--resume]
# main.py: error: the following arguments are required: --config
# run-naive-sequential.sh: line 13: --config: command not found

# %%
# %%bash
#
# sed -i 's/\r$//' run-naive-sequential.sh
# chmod +x run-naive-sequential.sh

# %%
# !bash run-naive-sequential.sh
# Out:
# 2026-03-10 19:25:03 | INFO     | dreambooth_clora | Loaded config from: configs/tasks_5char_naive.yaml
# 2026-03-10 19:25:03 | INFO     | dreambooth_clora | Experiment: 5char_naive
# 2026-03-10 19:25:03 | INFO     | dreambooth_clora | Method: naive_sequential
# 2026-03-10 19:25:03 | INFO     | dreambooth_clora | Tasks: 3
# 2026-03-10 19:25:03 | INFO     | dreambooth_clora | Output: /workspace/Continual-DreamBooth-LoRA/configs/../outputs/naive-sequential/debug
# 2026-03-10 19:25:03 | INFO     | dreambooth_clora | Global seed set to 42
# 2026-03-10 19:25:03 | INFO     | orchestrator.pipeline | ============================================================
# 2026-03-10 19:25:03 | INFO     | orchestrator.pipeline | CONTINUAL DREAMBOOTH-CLORA PIPELINE (LEGACY)
# 2026-03-10 19:25:03 | INFO     | orchestrator.pipeline | Method: naive_sequential
# 2026-03-10 19:25:03 | INFO     | orchestrator.pipeline | Tasks: 3
# ...

# %%
# !bash run-scaffold.sh
# Out:
# 2026-03-10 21:14:59 | INFO     | dreambooth_clora | Loaded config from: configs/tasks_5char_scaffold.yaml
# 2026-03-10 21:14:59 | INFO     | dreambooth_clora | Experiment: 5char_scaffold
# 2026-03-10 21:14:59 | INFO     | dreambooth_clora | Method: c_lora_scaffold
# 2026-03-10 21:14:59 | INFO     | dreambooth_clora | Tasks: 3
# 2026-03-10 21:14:59 | INFO     | dreambooth_clora | Output: /workspace/Continual-DreamBooth-LoRA/configs/../outputs/c-lora-scaffold/debug
# 2026-03-10 21:14:59 | INFO     | dreambooth_clora | Global seed set to 42
# 2026-03-10 21:14:59 | INFO     | orchestrator.pipeline | ============================================================
# 2026-03-10 21:14:59 | INFO     | orchestrator.pipeline | CONTINUAL DREAMBOOTH-CLORA PIPELINE (LEGACY)
# 2026-03-10 21:14:59 | INFO     | orchestrator.pipeline | Method: c_lora_scaffold
# 2026-03-10 21:14:59 | INFO     | orchestrator.pipeline | Tasks: 3
# ...

# %%
# %%bash
#
# sed -i 's/\r$//' run-faithful.sh
# chmod +x run-faithful.sh

# %%
# !bash run-faithful.sh
# Out:
# 2026-03-10 21:29:05 | INFO     | dreambooth_clora | Loaded config from: configs/tasks_5char_faithful.yaml
# 2026-03-10 21:29:05 | INFO     | dreambooth_clora | Experiment: 5char_faithful
# 2026-03-10 21:29:05 | INFO     | dreambooth_clora | Method: faithful_c_lora
# 2026-03-10 21:29:05 | INFO     | dreambooth_clora | Tasks: 3
# 2026-03-10 21:29:05 | INFO     | dreambooth_clora | Output: /workspace/Continual-DreamBooth-LoRA/configs/../outputs/faithful/debug
# 2026-03-10 21:29:05 | INFO     | dreambooth_clora | Global seed set to 42
# 2026-03-10 21:29:05 | INFO     | orchestrator.pipeline | ============================================================
# 2026-03-10 21:29:05 | INFO     | orchestrator.pipeline | FAITHFUL C-LORA PIPELINE
# 2026-03-10 21:29:05 | INFO     | orchestrator.pipeline | Tasks: 3
# 2026-03-10 21:29:05 | INFO     | orchestrator.pipeline | Regularizer: occupancy (λ=0.1000)
# 2026-03-10 21:29:05 | INFO     | orchestrator.pipeline | Token init: random
# ...

# %%
# !bash test-base-model.sh
# Out:
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Repo root: /workspace/DreamBooth-CLoRA
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Config: /workspace/DreamBooth-CLoRA/configs/tasks_5char.yaml
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Selected task: Miku
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Prompt mode: dreambooth
# 2026-03-08 22:50:01 | INFO     | dreambooth_clora | Output dir: /workspace/DreamBooth-CLoRA/configs/../outputs/naive-sequential-learning-debug/02/debug/base_model_preview/Miku
# 2026-03-08 22:50:02 | INFO     | src.training.trainer | Loading base model: hakurei/waifu-diffusion
# `torch_dtype` is deprecated! Use `dtype` instead!
# 2026-03-08 22:50:05 | INFO     | src.training.trainer | Base models loaded and frozen
# Loading pipeline components...: 100%|█████████████| 6/6 [00:00<00:00, 12.27it/s]
# 2026-03-08 22:50:06 | INFO     | src.eval.generator | Generating 4 images for prompt 1/6: 'sksmiku, portrait, white background'
# ...
